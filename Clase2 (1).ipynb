# %% [markdown]
# # Curso de Machine Learning Python
# https://www.ucentral.edu.co/dec/curso-machine-learning-python
# - Nombre: José Fernando Zea Castro
# - Email: jfzeac@gmail.com

# %% [markdown]
# # Pandas

# %% [markdown]
#  Por lo generar viene preinstalado pip install pandas

# %% [markdown]
# La serie es la estructura básica de pandas:

# %%
import pandas as pd
import numpy as np

x = [10, 20, 30, 40]
serie = pd.Series(x)
print(serie)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
serie.index = ['a', 'b', 'c', 'd']
serie
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
serie.median()
# Out:
# 25.0

# %%
serie.shape
# Out:
# (4,)

# %%
array = np.array([100, 200, 300])
print(array)
# Out:
# [100 200 300]

# %%
array.shape
# Out:
# (3,)

# %%
datos = {'a': 10, 'b': 20, 'c': 30}
serie = pd.Series(datos)
print(serie)

array = np.array([100, 200, 300])
serie = pd.Series(array)
print(serie)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
serie.index = ['A', 'B', 'C']
print(serie)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %% [markdown]
# Las Series permiten elaborar los dataframes:

# %%
# Data Frame

datos = {
    'Nombre': ['Ana', 'Juan', 'Luis'],
    'Edad': [25, 30, 22],
    'Ciudad': ['Bogotá', 'Medellín', 'Cali']
}
df = pd.DataFrame(datos)
print(df)
# Out:
#   Nombre  Edad    Ciudad
# 0    Ana    25    Bogotá
# 1   Juan    30  Medellín
# 2   Luis    22      Cali

# %%
df.columns
# Out:
# Index(['Nombre', 'Edad', 'Ciudad'], dtype='object')

# %%
# Desde un array de NumPy

array = np.array([[1, 2, 3], [4, 5, 6]])
df = pd.DataFrame(array, columns=['A', 'B', 'C'])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
# A partir de una lista
datos = [[1, 'Ana', 25], [2, 'Juan', 30], [3, 'Luis', 22]]
df = pd.DataFrame(datos, columns=['ID', 'Nombre', 'Edad'])
print(df)
# Out:
#    ID Nombre  Edad
# 0   1    Ana    25
# 1   2   Juan    30
# 2   3   Luis    22

# %%
df.Edad
#df['Edad']
# Out:
# 0    25
# 1    30
# 2    22
# Name: Edad, dtype: int64

# %%
# Características de un pandas dataframe

print(df.columns)
print(df.shape)
print(df.dtypes)
# Out:
# Index(['ID', 'Nombre', 'Edad'], dtype='object')
# (3, 3)
# ID         int64
# Nombre    object
# Edad       int64
# dtype: object

# %%
# Encabezado
df.head(n = 2)
# Out:
#    ID Nombre  Edad
# 0   1    Ana    25
# 1   2   Juan    30

# %%
# ültimos valores
df.tail(n = 2)
# Out:
#    ID Nombre  Edad
# 1   2   Juan    30
# 2   3   Luis    22

# %%
df
# Out:
#    ID Nombre  Edad
# 0   1    Ana    25
# 1   2   Juan    30
# 2   3   Luis    22

# %%
print(df['Nombre'])  # Devuelve una Serie df.Nombre
#print(df.iloc[:,1])  # Primera fila
# Out:
# 0     Ana
# 1    Juan
# 2    Luis
# Name: Nombre, dtype: object

# %%
#print(df[df['Edad'] > 25])  # Filtrar mayores de 25 años

# Mofiicación de datos
df['Salario'] = [50000, 60000, 55000]
print(df)
# Out:
#    ID Nombre  Edad  Salario
# 0   1    Ana    25    50000
# 1   2   Juan    30    60000
# 2   3   Luis    22    55000

# %%
# Eliminar columna
df = df.drop(columns=['Salario'])

df.loc[0, 'Edad'] = 26
print(df)
# Out:
#    ID Nombre  Edad
# 0   1    Ana    26
# 1   2   Juan    30
# 2   3   Luis    22

# %%
df.index = ['a', 'b', 'c']
df.loc['a', 'Edad'] = 36
print(df)
# Out:
#    ID Nombre  Edad
# a   1    Ana    36
# b   2   Juan    30
# c   3   Luis    22

# %%
df.loc['a', ['ID', 'Edad']]
# Out:
# ID       1
# Edad    36
# Name: a, dtype: object

# %%
df.iloc[1,2]=60
print(df)
# Out:
#    ID Nombre  Edad
# a   1    Ana    36
# b   2   Juan    60
# c   3   Luis    22

# %% [markdown]
# # Operaciones comunes en un pandas dataframe

# %% [markdown]
# Cargamos un pandas dataframe de juguete para ilustrar algunas de las principales funcionalidades del dataframe:

# %%
import pandas as pd
from seaborn import load_dataset

# Cargar el dataset de iris
iris = load_dataset("iris")

# Renombrar columnas para reemplazar '.' por '_'
iris.columns = iris.columns.str.replace('.', '_', regex=False)

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Renombrar variables

# %%
iris_renamed = iris.rename(columns={'sepal_length': 'longitud_sepalo', 'petal_length': 'longitud_petalo'})
print(iris_renamed)
# Out:
#      longitud_sepalo  sepal_width  longitud_petalo  petal_width    species
# 0                5.1          3.5              1.4          0.2     setosa
# 1                4.9          3.0              1.4          0.2     setosa
# 2                4.7          3.2              1.3          0.2     setosa
# 3                4.6          3.1              1.5          0.2     setosa
# 4                5.0          3.6              1.4          0.2     setosa
# ..               ...          ...              ...          ...        ...
# 145              6.7          3.0              5.2          2.3  virginica
# 146              6.3          2.5              5.0          1.9  virginica
# 147              6.5          3.0              5.2          2.0  virginica
# 148              6.2          3.4              5.4          2.3  virginica
# 149              5.9          3.0              5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Selección de variables (columnas)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Lista de columnas a quitar
quitar = ['sepal_length', 'species']

# Crear un booleano que identifica las columnas a conservar
conservar = ~iris.columns.isin(quitar)

# Seleccionar las columnas a conservar y mostrarlas
iris_filtrado = iris.loc[:, conservar]

print(iris_filtrado)
# Out:
#      sepal_width  petal_length  petal_width
# 0            3.5           1.4          0.2
# 1            3.0           1.4          0.2
# 2            3.2           1.3          0.2
# 3            3.1           1.5          0.2
# 4            3.6           1.4          0.2
# ..           ...           ...          ...
# 145          3.0           5.2          2.3
# 146          2.5           5.0          1.9
# 147          3.0           5.2          2.0
# 148          3.4           5.4          2.3
# 149          3.0           5.1          1.8
#
# [150 rows x 3 columns]

# %%
iris_filtrado2 = iris.drop(columns = quitar)
print(iris_filtrado2)
# Out:
#      sepal_width  petal_length  petal_width
# 0            3.5           1.4          0.2
# 1            3.0           1.4          0.2
# 2            3.2           1.3          0.2
# 3            3.1           1.5          0.2
# 4            3.6           1.4          0.2
# ..           ...           ...          ...
# 145          3.0           5.2          2.3
# 146          2.5           5.0          1.9
# 147          3.0           5.2          2.0
# 148          3.4           5.4          2.3
# 149          3.0           5.1          1.8
#
# [150 rows x 3 columns]

# %%
iris[['sepal_length', 'species']]
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
#iris_selected = iris.loc[:, ['sepal_length', 'species']]
iris_selected = iris.iloc[:, [0, -1]]  # Primera y última columna (Alternativamente)

print(iris_selected)
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# Existe un método específico para seleccioanr columnas:

# %%
# iris[['sepal_length', 'no_existe']]

# %%
iris.filter(items=['sepal_length', 'no_existe'])  # No falla, solo ignora 'no_existe'
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %% [markdown]
# Uso de variables que contengan like:

# %%
iris.filter(like='sepal')
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# Palabras que empiecen por petal:

# %%
iris.filter(regex='^petal.*')
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %% [markdown]
# # Selección de filas

# %% [markdown]
# Puedo tambien seleccioanr algunas filas:

# %%
iris_selected = iris.iloc[[0, 2, 4]]  # Python uses zero-based indexing
iris_selected.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import pandas as pd
from seaborn import load_dataset

# Cargar el dataset de iris
iris = load_dataset("iris")

# Renombrar columnas para reemplazar '.' por '_'
iris.columns = iris.columns.str.replace('.', '_', regex=False)

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.index = ['flor_' + str(i) for i in iris.index]

iris.index
# Out:
# Index(['flor_0', 'flor_1', 'flor_2', 'flor_3', 'flor_4', 'flor_5', 'flor_6',
#        'flor_7', 'flor_8', 'flor_9',
#        ...
#        'flor_140', 'flor_141', 'flor_142', 'flor_143', 'flor_144', 'flor_145',
#        'flor_146', 'flor_147', 'flor_148', 'flor_149'],
#       dtype='object', length=150)

# %%
iris.loc[['flor_0', 'flor_2']]
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# flor_0           5.1          3.5           1.4          0.2  setosa
# flor_2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# Puedo eliminar algunas filas:

# %%
import pandas as pd
from seaborn import load_dataset

# Cargar el dataset de iris
iris = load_dataset("iris")

# Renombrar columnas para reemplazar '.' por '_'
iris.columns = iris.columns.str.replace('.', '_', regex=False)

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.drop([0, 1], axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [148 rows x 5 columns]

# %% [markdown]
# Python soporta temas multindex:

# %%
tuplas = [('Frutas', 'Manzana'), ('Frutas', 'Banana'), ('Verduras', 'Zanahoria')]
index = pd.MultiIndex.from_tuples(tuplas, names=['Categoría', 'Producto'])

df_multi = pd.DataFrame({'Precio': [10, 20, 15]}, index=index)

print(df_multi)
# Out:
#                      Precio
# Categoría Producto
# Frutas    Manzana        10
#           Banana         20
# Verduras  Zanahoria      15

# %% [markdown]
# Podemos seleccioanr variables:

# %%
print(df_multi.loc[('Frutas', 'Manzana')])  # Accede solo a "Manzana"
# Out:
# Precio    10
# Name: (Frutas, Manzana), dtype: int64

# %% [markdown]
# Creemos un multiindex para la base de datos iris:

# %%
# Suponiendo que 'iris' ya es un DataFrame de pandas
iris_multiindex = iris.set_index(['species', iris.index])

# Renombrar los niveles del índice
iris_multiindex.index.names = ['species', 'sequence']

# Mostrar el resultado
print(iris_multiindex)
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width
# species   sequence
# setosa    0                  5.1          3.5           1.4          0.2
#           1                  4.9          3.0           1.4          0.2
#           2                  4.7          3.2           1.3          0.2
#           3                  4.6          3.1           1.5          0.2
#           4                  5.0          3.6           1.4          0.2
# ...                          ...          ...           ...          ...
# virginica 145                6.7          3.0           5.2          2.3
#           146                6.3          2.5           5.0          1.9
#           147                6.5          3.0           5.2          2.0
#           148                6.2          3.4           5.4          2.3
#           149                5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Observemos el multindex:

# %%
iris_multiindex.index.tolist()
# Out:
# [('setosa', 0),
#  ('setosa', 1),
#  ('setosa', 2),
#  ('setosa', 3),
#  ('setosa', 4),
#  ('setosa', 5),
#  ('setosa', 6),
#  ('setosa', 7),
#  ('setosa', 8),
#  ('setosa', 9),
#  ('setosa', 10),
#  ('setosa', 11),
#  ('setosa', 12),
#  ('setosa', 13),
#  ('setosa', 14),
#  ('setosa', 15),
#  ('setosa', 16),
#  ('setosa', 17),
#  ('setosa', 18),
#  ('setosa', 19),
#  ('setosa', 20),
#  ('setosa', 21),
#  ('setosa', 22),
#  ('setosa', 23),
#  ('setosa', 24),
#  ('setosa', 25),
#  ('setosa', 26),
#  ('setosa', 27),
#  ('setosa', 28),
#  ('setosa', 29),
#  ('setosa', 30),
#  ('setosa', 31),
#  ('setosa', 32),
#  ('setosa', 33),
#  ('setosa', 34),
#  ('setosa', 35),
#  ('setosa', 36),
#  ('setosa', 37),
#  ('setosa', 38),
#  ('setosa', 39),
#  ('setosa', 40),
#  ('setosa', 41),
#  ('setosa', 42),
#  ('setosa', 43),
#  ('setosa', 44),
#  ('setosa', 45),
#  ('setosa', 46),
#  ('setosa', 47),
#  ('setosa', 48),
#  ('setosa', 49),
#  ('versicolor', 50),
#  ('versicolor', 51),
#  ('versicolor', 52),
#  ('versicolor', 53),
#  ('versicolor', 54),
#  ('versicolor', 55),
#  ('versicolor', 56),
#  ('versicolor', 57),
#  ('versicolor', 58),
#  ('versicolor', 59),
#  ('versicolor', 60),
#  ('versicolor', 61),
#  ('versicolor', 62),
#  ('versicolor', 63),
#  ('versicolor', 64),
#  ('versicolor', 65),
#  ('versicolor', 66),
#  ('versicolor', 67),
#  ('versicolor', 68),
#  ('versicolor', 69),
#  ('versicolor', 70),
#  ('versicolor', 71),
#  ('versicolor', 72),
#  ('versicolor', 73),
#  ('versicolor', 74),
#  ('versicolor', 75),
#  ('versicolor', 76),
#  ('versicolor', 77),
#  ('versicolor', 78),
#  ('versicolor', 79),
#  ('versicolor', 80),
#  ('versicolor', 81),
#  ('versicolor', 82),
#  ('versicolor', 83),
#  ('versicolor', 84),
#  ('versicolor', 85),
#  ('versicolor', 86),
#  ('versicolor', 87),
#  ('versicolor', 88),
#  ('versicolor', 89),
#  ('versicolor', 90),
#  ('versicolor', 91),
#  ('versicolor', 92),
#  ('versicolor', 93),
#  ('versicolor', 94),
#  ('versicolor', 95),
#  ('versicolor', 96),
#  ('versicolor', 97),
#  ('versicolor', 98),
#  ('versicolor', 99),
#  ('virginica', 100),
#  ('virginica', 101),
#  ('virginica', 102),
#  ('virginica', 103),
#  ('virginica', 104),
#  ('virginica', 105),
#  ('virginica', 106),
#  ('virginica', 107),
#  ('virginica', 108),
#  ('virginica', 109),
#  ('virginica', 110),
#  ('virginica', 111),
#  ('virginica', 112),
#  ('virginica', 113),
#  ('virginica', 114),
#  ('virginica', 115),
#  ('virginica', 116),
#  ('virginica', 117),
#  ('virginica', 118),
#  ('virginica', 119),
#  ('virginica', 120),
#  ('virginica', 121),
#  ('virginica', 122),
#  ('virginica', 123),
#  ('virginica', 124),
#  ('virginica', 125),
#  ('virginica', 126),
#  ('virginica', 127),
#  ('virginica', 128),
#  ('virginica', 129),
#  ('virginica', 130),
#  ('virginica', 131),
#  ('virginica', 132),
#  ('virginica', 133),
#  ('virginica', 134),
#  ('virginica', 135),
#  ('virginica', 136),
#  ('virginica', 137),
#  ('virginica', 138),
#  ('virginica', 139),
#  ('virginica', 140),
#  ('virginica', 141),
#  ('virginica', 142),
#  ('virginica', 143),
#  ('virginica', 144),
#  ('virginica', 145),
#  ('virginica', 146),
#  ('virginica', 147),
#  ('virginica', 148),
#  ('virginica', 149)]

# %% [markdown]
# Podemos filtrar por multiindex:

# %%
iris_multiindex.loc[[('setosa', 1), ('setosa', 3), ('virginica', 145)]]
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width
# species   sequence
# setosa    1                  4.9          3.0           1.4          0.2
#           3                  4.6          3.1           1.5          0.2
# virginica 145                6.7          3.0           5.2          2.3

# %%
# Crear un MultiIndex con la especie y la secuencia del índice original
iris.set_index(['species', iris.index], inplace=True)

# Renombrar los niveles del índice
df.index.names = ['species', 'sequence']

print(df)

# %% [markdown]
# # Eliminar variables

# %%
iris_selected2 = iris.drop(columns=['sepal_length', 'petal_length'])
print(iris_selected2)
# Out:
#      sepal_width  petal_width    species
# 0            3.5          0.2     setosa
# 1            3.0          0.2     setosa
# 2            3.2          0.2     setosa
# 3            3.1          0.2     setosa
# 4            3.6          0.2     setosa
# ..           ...          ...        ...
# 145          3.0          2.3  virginica
# 146          2.5          1.9  virginica
# 147          3.0          2.0  virginica
# 148          3.4          2.3  virginica
# 149          3.0          1.8  virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# # Duplicados

# %%
import pandas as pd

# Ejemplo de DataFrame
data = {'id': [1, 2, 2, 3, 4, 4, 4], 'valor': [10, 20, 20, 30, 40, 40, 40]}
df = pd.DataFrame(data)
print(df)
# Out:
#    id  valor
# 0   1     10
# 1   2     20
# 2   2     20
# 3   3     30
# 4   4     40
# 5   4     40
# 6   4     40

# %%
df['id'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# Name: id, dtype: bool

# %%
df['id'].duplicated().value_counts()
# Out:
# id
# False    4
# True     3
# Name: count, dtype: int64

# %%
# Seleccionar filas donde 'id' no es duplicado
df_sin_duplicados = df[~df['id'].duplicated()]
print(df_sin_duplicados)
# Out:
#    id  valor
# 0   1     10
# 1   2     20
# 3   3     30
# 4   4     40

# %%
# Seleccionar todas las filas duplicadas (desde el inicio o desde el final)
duplicados = df[df['id'].duplicated(keep='first') | df['id'].duplicated(keep='last')]
print(duplicados)
# Out:
#    id  valor
# 1   2     20
# 2   2     20
# 4   4     40
# 5   4     40
# 6   4     40

# %%
data = {'id': [1, 2, 2, 3, 4, 4, 4], 'valor': [10, 20, 20, 30, 40, 40, 40]}
df = pd.DataFrame(data)
print(df)
# Out:
#    id  valor
# 0   1     10
# 1   2     20
# 2   2     20
# 3   3     30
# 4   4     40
# 5   4     40
# 6   4     40

# %%
# Eliminar duplicados considerando solo la primera aparición
df_sin_duplicados = df.drop_duplicates(subset='id', keep='first')

# Eliminar duplicados sin mantener ninguna aparición
df_sin_repetidos = df.drop_duplicates(subset='id', keep=False)
print(df_sin_duplicados)
# Out:
#    id  valor
# 0   1     10
# 1   2     20
# 3   3     30
# 4   4     40

# %%
print(df_sin_duplicados)
# Out:
#    id  valor
# 0   1     10
# 1   2     20
# 3   3     30
# 4   4     40

# %%
# Multiples columnas
import pandas as pd

# Define the data as a dictionary
data = {
    "Id_dpto": ["cod005", "cod11", "cod76", "cod005", "cod008", "cod005"],
    "Id_municio": ["cod001", "cod001", "cod001", "cod001", "cod001", "cod001"],
    "Municipio": ["Medellin", "Bogota", "Cali", "Medellin", "Barranquilla", "Medellin"],
    "Poblacion": [2.5, 8, 2.4, 2.5, 1.9, 2.5]
}

# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(data)

print(df)

# %%
iris_summary = iris.groupby('species', as_index=False).agg(prom_sepalLengthSpecie=('sepal_length', 'mean'))

# %%
# Agrupar por 'species' y calcular media y mediana para sepal_length y sepal_width
iris_summary = iris.groupby('species', as_index=False).agg(
    prom_sepalLengthSpecie=('sepal_length', 'mean'),
    mediana_sepalLengthSpecie=('sepal_length', 'median'),
    prom_sepalWidthSpecie=('sepal_width', 'mean'),
    mediana_sepalWidthSpecie=('sepal_width', 'median')
)

print(iris_summary)
# Out:
#       species  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  prom_sepalWidthSpecie  mediana_sepalWidthSpecie
# 0      setosa                   5.006                        5.0                  3.428                       3.4
# 1  versicolor                   5.936                        5.9                  2.770                       2.8
# 2   virginica                   6.588                        6.5                  2.974                       3.0

# %%
import pandas as pd

# Define the data as a dictionary
data_mpios = {
    "Id_dpto": ["cod005", "cod11", "cod76", "cod005", "cod008", "cod005"],
    "Id_municio": ["cod001", "cod001", "cod001", "cod001", "cod001", "cod001"],
    "Municipio": ["Medellin", "Bogota", "Cali", "Medellin", "Barranquilla", "Medellin"],
    "Poblacion": [2.5, 8, 2.4, 2.5, 1.9, 2.5]
}

# Create a pandas DataFrame from the dictionary
df_mpios = pd.DataFrame(data_mpios)
df_mpios_sin_duplicados = df_mpios.drop_duplicates(subset=['Id_dpto', 'Id_municio'], keep='first')

print(df_mpios_sin_duplicados)
# Out:
#   Id_dpto Id_municio     Municipio  Poblacion
# 0  cod005     cod001      Medellin        2.5
# 1   cod11     cod001        Bogota        8.0
# 2   cod76     cod001          Cali        2.4
# 4  cod008     cod001  Barranquilla        1.9

# %%
df.columns
# Out:
# Index(['id', 'valor'], dtype='object')

# %%
filtro = df[['Id_dpto', 'Id_municio' ]].duplicated()
df[~filtro]

df['id'] = df['Id_dpto'] + df['Id_municio']
filtro2 = df[['id']].duplicated()
df[~filtro2]
# Out:
#   Id_dpto Id_municio     Municipio  Poblacion            id
# 0  cod005     cod001      Medellin        2.5  cod005cod001
# 1   cod11     cod001        Bogota        8.0   cod11cod001
# 2   cod76     cod001          Cali        2.4   cod76cod001
# 4  cod008     cod001  Barranquilla        1.9  cod008cod001

# %% [markdown]
# # Transformación

# %% [markdown]
# Crear un consecutivo:

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {'nombre': ['Ana', 'Luis', 'María', 'Juan']}
df = pd.DataFrame(data)

# Crear una columna con números consecutivos
df['id'] = range(1, len(df) + 1)  # Desde 1 hasta el número de filas

print(df)
# Out:
#   nombre  id
# 0    Ana   1
# 1   Luis   2
# 2  María   3
# 3   Juan   4

# %% [markdown]
# Crear el índice de masa corporal:

# %%
# Crear un DataFrame de ejemplo
data = {'nombre': ['Ana', 'Luis', 'María', 'Juan'],
        'peso': [60, 75, 55, 80],
        'altura': [1.65, 1.80, 1.55, 1.75]}
df = pd.DataFrame(data)

print(df)
# Out:
#   nombre  peso  altura
# 0    Ana    60    1.65
# 1   Luis    75    1.80
# 2  María    55    1.55
# 3   Juan    80    1.75

# %%
# Calcular el IMC y agregarlo como nueva columna
df['imc'] = df['peso'] / (df['altura'] ** 2)
df['log_peso'] = np.log(df['peso'])
print(df)
# apply
# Out:
#   nombre  peso  altura        imc  log_peso
# 0    Ana    60    1.65  22.038567  4.094345
# 1   Luis    75    1.80  23.148148  4.317488
# 2  María    55    1.55  22.892820  4.007333
# 3   Juan    80    1.75  26.122449  4.382027

# %%
import pandas as pd

# Sample DataFrame
data = {
    "shop_id": [1, 2, 3],
    "ventas_1": [100, 200, 300],
    "ventas_2": [150, 250, 350],
    "ventas_3": [200, 300, 400],
    "ventas_4": [180, 220, 320]
}
data = pd.DataFrame(data)

print(data)
# Out:
#    shop_id  ventas_1  ventas_2  ventas_3  ventas_4
# 0        1       100       150       200       180
# 1        2       200       250       300       220
# 2        3       300       350       400       320

# %%
df = pd.DataFrame(data)

# Compute the average for each shop using apply
df["average_ventas"] = df.loc[:, "ventas_1":"ventas_4"].apply(lambda row: row.mean(), axis=1)

print(df)
# Out:
#    shop_id  ventas_1  ventas_2  ventas_3  ventas_4  average_ventas
# 0        1       100       150       200       180           157.5
# 1        2       200       250       300       220           242.5
# 2        3       300       350       400       320           342.5

# %% [markdown]
# Crear el ingreso total:

# %%
# Crear un DataFrame de ejemplo
data = {'ingreso_suscripcion': [500, 600, 700],
        'ingreso_publicidad': [300, 400, 500]}
df = pd.DataFrame(data)

# Calcular el ingreso total
df['ingreso_total'] = df['ingreso_suscripcion'] + df['ingreso_publicidad']

print(df)
# Out:
#    ingreso_suscripcion  ingreso_publicidad  ingreso_total
# 0                  500                 300            800
# 1                  600                 400           1000
# 2                  700                 500           1200

# %% [markdown]
# Usar assign para cálculos similares:

# %%
import pandas as pd

# DataFrame inicial
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})

# Crear nuevas columnas con assign
df_nuevo = df.assign(c=df['a'] + df['b'], d=df['a'] * 2)

print(df_nuevo)
# Out:
#    a  b  c  d
# 0  1  4  5  2
# 1  2  5  7  4
# 2  3  6  9  6

# %% [markdown]
# Función trasnform sin agrupar:

# %%
import pandas as pd

# DataFrame inicial
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})

# Crear nuevas columnas
df['c'] = df.apply(lambda x: x['a'] + x['b'], axis=1)  # Suma de 'a' y 'b'
df['d'] = df['a'].transform(lambda x: x * 2)          # Doble de 'a'

print(df)
# Out:
#    a  b  c  d
# 0  1  4  5  2
# 1  2  5  7  4
# 2  3  6  9  6

# %% [markdown]
# # Transformación agrupada

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#iris['prom_sepalLength'] = iris['sepal_length'].transform(lambda _: iris['sepal_length'].mean())
iris['prom_sepalLength'].mean()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  \
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
#    prom_sepalLength
# 0          5.843333
# 1          5.843333
# 2          5.843333
# 3          5.843333
# 4          5.843333

# %%
# Aplicar transform() separadamente para cada estadística
iris['prom_sepalLengthSpecie'] = iris.groupby('species')['sepal_length'].transform('mean')
iris['mediana_sepalLengthSpecie'] = iris.groupby('species')['sepal_length'].transform('median')
iris['prom_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform('mean')
iris['mediana_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform('median')
iris['q25_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform(lambda x: x.quantile(0.25))
iris['cve_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform(
    lambda x: 100 * x.std() / x.mean()
)

#def cve(x):
#  100 * x.std() / x.mean()

print(iris.head())
#print(iris.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      prom_sepalLength  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  \
# 145          5.843333                   6.588                        6.5
# 146          5.843333                   6.588                        6.5
# 147          5.843333                   6.588                        6.5
# 148          5.843333                   6.588                        6.5
# 149          5.843333                   6.588                        6.5
#
#      prom_sepalWidthSpecie  mediana_sepalWidthSpecie  q25_sepalWidthSpecie  \
# 145                  2.974                       3.0                   2.8
# 146                  2.974                       3.0                   2.8
# 147                  2.974                       3.0                   2.8
# 148                  2.974                       3.0                   2.8
# 149                  2.974                       3.0                   2.8
#
#      cve_sepalWidthSpecie
# 145             10.843868
# 146             10.843868
# 147             10.843868
# 148             10.843868
# 149             10.843868

# %% [markdown]
# # Agregaciones

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      prom_sepalLength  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  \
# 0            5.843333                   5.006                        5.0
# 1            5.843333                   5.006                        5.0
# 2            5.843333                   5.006                        5.0
# 3            5.843333                   5.006                        5.0
# 4            5.843333                   5.006                        5.0
# ..                ...                     ...                        ...
# 145          5.843333                   6.588                        6.5
# 146          5.843333                   6.588                        6.5
# 147          5.843333                   6.588                        6.5
# 148          5.843333                   6.588                        6.5
# 149          5.843333                   6.588                        6.5
#
#      prom_sepalWidthSpecie  mediana_sepalWidthSpecie  q25_sepalWidthSpecie  \
# 0                    3.428                       3.4                   3.2
# 1                    3.428                       3.4                   3.2
# 2                    3.428                       3.4                   3.2
# 3                    3.428                       3.4                   3.2
# 4                    3.428                       3.4                   3.2
# ..                     ...                       ...                   ...
# 145                  2.974                       3.0                   2.8
# 146                  2.974                       3.0                   2.8
# 147                  2.974                       3.0                   2.8
# 148                  2.974                       3.0                   2.8
# 149                  2.974                       3.0                   2.8
#
#      cve_sepalWidthSpecie
# 0               11.057887
# 1               11.057887
# 2               11.057887
# 3               11.057887
# 4               11.057887
# ..                    ...
# 145             10.843868
# 146             10.843868
# 147             10.843868
# 148             10.843868
# 149             10.843868
#
# [150 rows x 12 columns]

# %%
# Calcular proporción de desertores en cada cuartil
df_summary1 = iris.groupby('species')['petal_length'].apply(lambda x: x.mean()).reset_index()
df_summary1
# Out:
#       species  petal_length
# 0      setosa         1.462
# 1  versicolor         4.260
# 2   virginica         5.552

# %%
# Agrupar por 'species' y calcular media y mediana para sepal_length y sepal_width
iris_summary = iris.groupby('species', as_index=False).agg(
    prom_sepalLengthSpecie=('sepal_length', 'mean'),
    mediana_sepalLengthSpecie=('sepal_length', 'median'),
    prom_sepalWidthSpecie=('sepal_width', 'mean'),
    mediana_sepalWidthSpecie=('sepal_width', 'median'),
    cve_sepalWidthSpecie=('sepal_width', lambda x: 100 * x.std() / x.mean())
)
print(iris_summary)
# Out:
#       species  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  \
# 0      setosa                   5.006                        5.0
# 1  versicolor                   5.936                        5.9
# 2   virginica                   6.588                        6.5
#
#    prom_sepalWidthSpecie  mediana_sepalWidthSpecie  cve_sepalWidthSpecie
# 0                  3.428                       3.4             11.057887
# 1                  2.770                       2.8             11.328459
# 2                  2.974                       3.0             10.843868

# %%
# Agrupar por 'species' y calcular media y mediana para sepal_length y sepal_width
iris_summary = iris.groupby('species').agg(
    prom_sepalLengthSpecie=('sepal_length', 'mean'),
    mediana_sepalLengthSpecie=('sepal_length', 'median'),
    prom_sepalWidthSpecie=('sepal_width', 'mean'),
    mediana_sepalWidthSpecie=('sepal_width', 'median'),
    cve_sepalWidthSpecie=('sepal_width', lambda x: 100 * x.std() / x.mean()
))
iris_summary.reset_index()
# Out:
#       species  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  \
# 0      setosa                   5.006                        5.0
# 1  versicolor                   5.936                        5.9
# 2   virginica                   6.588                        6.5
#
#    prom_sepalWidthSpecie  mediana_sepalWidthSpecie  cve_sepalWidthSpecie
# 0                  3.428                       3.4             11.057887
# 1                  2.770                       2.8             11.328459
# 2                  2.974                       3.0             10.843868

# %% [markdown]
# # Análisis de datos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#     Algunas de las variables, tenures: número de meses que ha tenido el servicio

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')  # Coerce invalid values to NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# # Recodificación en percentiles (cuartiles, deciles, etc):

# %% [markdown]
# Para efectos de visualización puede ser muy interesante evaluar si existe una relación entre la deserción y la permanencia, para eso crearemos una variable recategorizada, creamos 4 clases:
# - min - P25
# - p25 - p50
# - p50 - p75
# - p75 max

# %%
bins = np.quantile(df['TotalCharges'], np.linspace(0, 1, 5))
print(bins)
# Out:
# [nan nan nan nan nan]

# %% [markdown]
# ¿Por que pasa lo anterior?, por que hay 11 valores faltantes:

# %%
df['TotalCharges'].isna().sum()
# Out:
# np.int64(11)

# %%
bins = np.quantile(df['TotalCharges'].dropna(), np.linspace(0, 1, 5))
print(bins)
# Out:
# [  18.8     401.45   1397.475  3794.7375 8684.8   ]

# %%
# Compute quantile-based bins

df['TotalChargesR'] = pd.cut(df['TotalCharges'] , bins=bins, labels=[1, 2, 3, 4],
include_lowest=True, right=False)
# Verificamos la cantidad:
print(df['TotalChargesR'].value_counts())
# Out:
# TotalChargesR
# 1    1758
# 2    1758
# 3    1758
# 4    1757
# Name: count, dtype: int64

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  \
# 0              Electronic check          29.85        29.85     No
# 1                  Mailed check          56.95      1889.50     No
# 2                  Mailed check          53.85       108.15    Yes
# 3     Bank transfer (automatic)          42.30      1840.75     No
# 4              Electronic check          70.70       151.65    Yes
# ...                         ...            ...          ...    ...
# 7038               Mailed check          84.80      1990.50     No
# 7039    Credit card (automatic)         103.20      7362.90     No
# 7040           Electronic check          29.60       346.45     No
# 7041               Mailed check          74.40       306.60    Yes
# 7042  Bank transfer (automatic)         105.65      6844.50     No
#
#       TotalChargesR
# 0                 1
# 1                 3
# 2                 1
# 3                 3
# 4                 1
# ...             ...
# 7038              3
# 7039              4
# 7040              1
# 7041              1
# 7042              4
#
# [7043 rows x 22 columns]

# %%
df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()
# Out:
# <ipython-input-203-4cf63edcafcf>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()
#   TotalChargesR     Churn
# 0             1  0.434585
# 1             2  0.253129
# 2             3  0.230375
# 3             4  0.144565

# %%
# Calcular proporción de desertores en cada cuartil
df_summary = df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()
df_summary.columns = ['Quartile', 'ChurnRate']
# Out:
# <ipython-input-204-4513123c5b3d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_summary = df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Datos de ejemplo
df_summary = pd.DataFrame({
    'Quartile': ['Q1', 'Q2', 'Q3', 'Q4'],
    'ChurnRate': [0.50, 0.75, 0.25, 0.40]
})

# Graficar
plt.figure(figsize=(8, 5))

# Gráfico de barras corregido
sns.barplot(data=df_summary, x='Quartile', y='ChurnRate', hue='Quartile', palette='Blues', legend=False)

# Línea de tendencia con plt.plot()
x = range(len(df_summary))  # Índices de los cuartiles
y = df_summary['ChurnRate']
plt.plot(x, y, color='red', linestyle='dashed', marker='o', markersize=6)

# Configuración del gráfico
plt.title("Proporción de Desertores por Cuartil de TotalCharges")
plt.xlabel("Cuartil de TotalCharges")
plt.ylabel("Proporción de Desertores")
plt.ylim(0, 1)
plt.xticks(x, df_summary['Quartile'])
plt.show()

# %%
# Análisis de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
#  21  TotalChargesR     7031 non-null   category
# dtypes: category(1), float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df['Churn'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 7038    <class 'str'>
# 7039    <class 'str'>
# 7040    <class 'str'>
# 7041    <class 'str'>
# 7042    <class 'str'>
# Name: Churn, Length: 7043, dtype: object

# %%
for col in df.columns:
    print(f"\nColumna: {col}")
    print(df[col].apply(type).value_counts())
# Out:
# Columna: customerID
# customerID
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: gender
# gender
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: SeniorCitizen
# SeniorCitizen
# <class 'int'>    7043
# Name: count, dtype: int64
#
# Columna: Partner
# Partner
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: Dependents
# Dependents
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: tenure
# tenure
# <class 'int'>    7043
# Name: count, dtype: int64
#
# Columna: PhoneService
# PhoneService
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: MultipleLines
# MultipleLines
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: InternetService
# InternetService
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: OnlineSecurity
# OnlineSecurity
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: OnlineBackup
# OnlineBackup
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: DeviceProtection
# DeviceProtection
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: TechSupport
# TechSupport
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: StreamingTV
# StreamingTV
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: StreamingMovies
# StreamingMovies
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: Contract
# Contract
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: PaperlessBilling
# PaperlessBilling
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: PaymentMethod
# PaymentMethod
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: MonthlyCharges
# MonthlyCharges
# <class 'float'>    7043
# Name: count, dtype: int64
#
# Columna: TotalCharges
# TotalCharges
# <class 'float'>    7043
# Name: count, dtype: int64
#
# Columna: Churn
# Churn
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: TotalChargesR
# TotalChargesR
# <class 'int'>    7031
# Name: count, dtype: int64

# %% [markdown]
# Revisemos las columnas que tienen un faltante

# %%
for col in df.columns:
    print(f"Columna: {col} - Faltantes: {df[col].isna().sum()}")
# Out:
# Columna: customerID - Faltantes: 0
# Columna: gender - Faltantes: 0
# Columna: SeniorCitizen - Faltantes: 0
# Columna: Partner - Faltantes: 0
# Columna: Dependents - Faltantes: 0
# Columna: tenure - Faltantes: 0
# Columna: PhoneService - Faltantes: 0
# Columna: MultipleLines - Faltantes: 0
# Columna: InternetService - Faltantes: 0
# Columna: OnlineSecurity - Faltantes: 0
# Columna: OnlineBackup - Faltantes: 0
# Columna: DeviceProtection - Faltantes: 0
# Columna: TechSupport - Faltantes: 0
# Columna: StreamingTV - Faltantes: 0
# Columna: StreamingMovies - Faltantes: 0
# Columna: Contract - Faltantes: 0
# Columna: PaperlessBilling - Faltantes: 0
# Columna: PaymentMethod - Faltantes: 0
# Columna: MonthlyCharges - Faltantes: 0
# Columna: TotalCharges - Faltantes: 11
# Columna: Churn - Faltantes: 0
# Columna: TotalChargesR - Faltantes: 12

# %% [markdown]
# Analizamos las variables continuas:

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# Sacar las variables categóricas:

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents  ...        Contract PaperlessBilling     PaymentMethod Churn
# count         7043   7043    7043       7043  ...            7043             7043              7043  7043
# unique        7043      2       2          2  ...               3                2                 4     2
# top     7590-VHVEG   Male      No         No  ...  Month-to-month              Yes  Electronic check    No
# freq             1   3555    3641       4933  ...            3875             4171              2365  5174
#
# [4 rows x 17 columns]

# %% [markdown]
# <!-- # Algunas lecturas sugeridas
# - https://log.schemescape.com/posts/programming-languages/python-as-a-modern-basic.html -->

# %% [markdown]
# # Agrupación

# %%
iris_summary = iris.groupby('species', as_index=False).agg(prom_sepalLengthSpecie=('sepal_length', 'mean'))

# %%
# Agrupar por 'species' y calcular media y mediana para sepal_length y sepal_width
iris_summary = iris.groupby('species', as_index=False).agg(
    prom_sepalLengthSpecie=('sepal_length', 'mean'),
    mediana_sepalLengthSpecie=('sepal_length', 'median'),
    prom_sepalWidthSpecie=('sepal_width', 'mean'),
    mediana_sepalWidthSpecie=('sepal_width', 'median')
)

print(iris_summary)
# Out:
#       species  prom_sepalLengthSpecie  mediana_sepalLengthSpecie  prom_sepalWidthSpecie  mediana_sepalWidthSpecie
# 0      setosa                   5.006                        5.0                  3.428                       3.4
# 1  versicolor                   5.936                        5.9                  2.770                       2.8
# 2   virginica                   6.588                        6.5                  2.974                       3.0

# %% [markdown]
# # Transformación agrupada

# %%
# Aplicar transform() separadamente para cada estadística
iris['prom_sepalLengthSpecie'] = iris.groupby('species')['sepal_length'].transform('mean')
iris['mediana_sepalLengthSpecie'] = iris.groupby('species')['sepal_length'].transform('median')
iris['prom_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform('mean')
iris['mediana_sepalWidthSpecie'] = iris.groupby('species')['sepal_width'].transform('median')

print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  ...  mediana_sepalLengthSpecie prom_sepalWidthSpecie  mediana_sepalWidthSpecie
# 0           5.1          3.5           1.4  ...                        5.0                 3.428                       3.4
# 1           4.9          3.0           1.4  ...                        5.0                 3.428                       3.4
# 2           4.7          3.2           1.3  ...                        5.0                 3.428                       3.4
# 3           4.6          3.1           1.5  ...                        5.0                 3.428                       3.4
# 4           5.0          3.6           1.4  ...                        5.0                 3.428                       3.4
#
# [5 rows x 9 columns]

# %% [markdown]
# # Análisis de datos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
#     Algunas de las variables, tenures: número de meses que ha tenido el servicio

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')  # Coerce invalid values to NaN

# %% [markdown]
# # Recodificación en percentiles (cuartiles, deciles, etc):

# %% [markdown]
# Para efectos de visualización puede ser muy interesante evaluar si existe una relación entre la deserción y la permanencia, para eso crearemos una variable recategorizada, creamos 4 clases:
# - min - P25
# - p25 - p50
# - p50 - p75
# - p75 max

# %%
bins = np.quantile(df['TotalCharges'], np.linspace(0, 1, 5))
print(bins)
# Out:
# array([nan, nan, nan, nan, nan])

# %% [markdown]
# ¿Por que pasa lo anterior?, por que hay 11 valores faltantes:

# %%
df['TotalCharges'].isna().sum()
# Out:
# 11

# %%
bins = np.quantile(df['TotalCharges'].dropna(), np.linspace(0, 1, 5))
print(bins)
# Out:
# [  18.8     401.45   1397.475  3794.7375 8684.8   ]

# %%
# Compute quantile-based bins

df['TotalChargesR'] = pd.cut(df['TotalCharges'] , bins=bins, labels=[1, 2, 3, 4],
include_lowest=True, right=False)
# Verificamos la cantidad:
print(df['TotalChargesR'].value_counts())
# Out:
# TotalChargesR
# 1    1758
# 2    1758
# 3    1758
# 4    1757
# Name: count, dtype: int64

# %%
df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()
# Out:
# <positron-console-cell-54>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   TotalChargesR     Churn
# 0             1  0.434585
# 1             2  0.253129
# 2             3  0.230375
# 3             4  0.144565

# %%
# Calcular proporción de desertores en cada cuartil
df_summary = df.groupby('TotalChargesR')['Churn'].apply(lambda x: (x == 'Yes').mean()).reset_index()
df_summary.columns = ['Quartile', 'ChurnRate']
# Out:
# <positron-console-cell-64>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# Análisis de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
#  21  TotalChargesR     7031 non-null   category
# dtypes: category(1), float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df['Churn'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 7038    <class 'str'>
# 7039    <class 'str'>
# 7040    <class 'str'>
# 7041    <class 'str'>
# 7042    <class 'str'>
# Name: Churn, Length: 7043, dtype: object

# %%
for col in df.columns:
    print(f"\nColumna: {col}")
    print(df[col].apply(type).value_counts())
# Out:
# Columna: customerID
# customerID
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: gender
# gender
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: SeniorCitizen
# SeniorCitizen
# <class 'int'>    7043
# Name: count, dtype: int64
#
# Columna: Partner
# Partner
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: Dependents
# Dependents
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: tenure
# tenure
# <class 'int'>    7043
# Name: count, dtype: int64
#
# Columna: PhoneService
# PhoneService
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: MultipleLines
# MultipleLines
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: InternetService
# InternetService
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: OnlineSecurity
# OnlineSecurity
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: OnlineBackup
# OnlineBackup
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: DeviceProtection
# DeviceProtection
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: TechSupport
# TechSupport
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: StreamingTV
# StreamingTV
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: StreamingMovies
# StreamingMovies
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: Contract
# Contract
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: PaperlessBilling
# PaperlessBilling
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: PaymentMethod
# PaymentMethod
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: MonthlyCharges
# MonthlyCharges
# <class 'float'>    7043
# Name: count, dtype: int64
#
# Columna: TotalCharges
# TotalCharges
# <class 'float'>    7043
# Name: count, dtype: int64
#
# Columna: Churn
# Churn
# <class 'str'>    7043
# Name: count, dtype: int64
#
# Columna: TotalChargesR
# TotalChargesR
# <class 'int'>    7031
# Name: count, dtype: int64

# %% [markdown]
# Revisemos las columnas que tienen un faltante

# %%
for col in df.columns:
    print(f"Columna: {col} - Faltantes: {df[col].isna().sum()}")
# Out:
# Columna: customerID - Faltantes: 0
# Columna: gender - Faltantes: 0
# Columna: SeniorCitizen - Faltantes: 0
# Columna: Partner - Faltantes: 0
# Columna: Dependents - Faltantes: 0
# Columna: tenure - Faltantes: 0
# Columna: PhoneService - Faltantes: 0
# Columna: MultipleLines - Faltantes: 0
# Columna: InternetService - Faltantes: 0
# Columna: OnlineSecurity - Faltantes: 0
# Columna: OnlineBackup - Faltantes: 0
# Columna: DeviceProtection - Faltantes: 0
# Columna: TechSupport - Faltantes: 0
# Columna: StreamingTV - Faltantes: 0
# Columna: StreamingMovies - Faltantes: 0
# Columna: Contract - Faltantes: 0
# Columna: PaperlessBilling - Faltantes: 0
# Columna: PaymentMethod - Faltantes: 0
# Columna: MonthlyCharges - Faltantes: 0
# Columna: TotalCharges - Faltantes: 11
# Columna: Churn - Faltantes: 0
# Columna: TotalChargesR - Faltantes: 12

# %% [markdown]
# Analizamos las variables continuas:

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# Sacar las variables categóricas:

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents  ...        Contract PaperlessBilling     PaymentMethod Churn
# count         7043   7043    7043       7043  ...            7043             7043              7043  7043
# unique        7043      2       2          2  ...               3                2                 4     2
# top     7590-VHVEG   Male      No         No  ...  Month-to-month              Yes  Electronic check    No
# freq             1   3555    3641       4933  ...            3875             4171              2365  5174
#
# [4 rows x 17 columns]

# %% [markdown]
# <!-- # Algunas lecturas sugeridas
# - https://log.schemescape.com/posts/programming-languages/python-as-a-modern-basic.html -->

# %% [markdown]
# # Algunas lecturas sugeridas y videos

# %% [markdown]
# - https://log.schemescape.com/posts/programming-languages/python-as-a-modern-basic.html
# - https://www.youtube.com/watch?v=LN2NbUkuddA
# -
